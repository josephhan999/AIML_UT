# %%
import pandas as pd

# %%
data = pd.read_csv('books.csv')

# %%
print(data)
# Out:
#                                                   title  \
# 0                           The Hunchback of Notre-Dame
# 1     La Cucina Di Lidia: Recipes and Memories from ...
# 2                                     Breach of Promise
# 3                     Brief Interviews with Hideous Men
# 4     The Killing Dance (Anita Blake  Vampire Hunter...
# ...                                                 ...
# 4995                                 The Complete Works
# 4996                               Shipwreck (Island I)
# 4997           Every Night Italian: Every Night Italian
# 4998                                     Go Down  Moses
# 4999  The Avignon Quintet: Monsieur  Livia  Constanc...
#
#                            author  average_rating         isbn13  \
# 0                     Victor Hugo            4.00  9780345472427
# 1     Lidia Matticchio Bastianich            4.14  9780767914222
# 2                James Scott Bell            4.00  9780310243878
# ...

# %%
data.describe()
# Out:
#        average_rating        isbn13    num_pages  ratings_count  \
# count     5000.000000  5.000000e+03  4967.000000   5.000000e+03
# mean         3.931932  9.752758e+12   341.094021   2.017549e+04
# std          0.348741  5.129254e+11   230.986115   1.175026e+05
# min          0.000000  8.987060e+09     1.000000   0.000000e+00
# 25%          3.770000  9.780345e+12   200.000000   1.050000e+02
# 50%          3.960000  9.780571e+12   304.000000   7.915000e+02
# 75%          4.140000  9.780871e+12   416.500000   5.348750e+03
# max          5.000000  9.789879e+12  3342.000000   2.457092e+06
#
#        text_reviews_count         year
# count         5000.000000  5000.000000
# mean           592.688600  2000.131800
# std           2539.539004     8.069043
# min              0.000000  1913.000000
# 25%              9.000000  1998.000000
# 50%             49.000000  2003.000000
# 75%            249.000000  2005.000000
# max          55843.000000  2019.000000

# %%
data['language_code']
# Out:
# 0       en-US
# 1       en-GB
# 2         eng
# 3         eng
# 4       en-US
#         ...
# 4995      eng
# 4996      eng
# 4997      eng
# 4998      eng
# 4999    en-US
# Name: language_code, Length: 5000, dtype: object

# %%
data['language_code'].isna().sum()
# Out:
# 77

# %%
data.columns
# Out:
# Index(['title', 'author', 'average_rating', 'isbn13', 'language_code',
#        'num_pages', 'ratings_count', 'text_reviews_count', 'publisher',
#        'year'],
#       dtype='object')

# %%
data['publisher'].nunique()
# Out:
# 1408

# %%
data[data['average_rating']>4].count()
# Out:
# title                 2115
# author                2115
# average_rating        2115
# isbn13                2115
# language_code         2072
# num_pages             2103
# ratings_count         2115
# text_reviews_count    2115
# publisher             2115
# year                  2115
# dtype: int64

# %%
data[data['language_code'] == 'NaN']
# Out:
# Empty DataFrame
# Columns: [title, author, average_rating, isbn13, language_code, num_pages, ratings_count, text_reviews_count, publisher, year]
# Index: []

# %%
data[data['language_code'].isnull()]
# Out:
#                                                   title  \
# 61                          Black Hole  tome 3: Visions
# 63                                             鋼之鍊金術師 9
# 108                              La Maison des feuilles
# 161   Jojo's Bizarre Adventure  Tome 14: Le Navire d...
# 172                                       O Historiador
# ...                                                 ...
# 4656                                          Galápagos
# 4742  Kenang-Kenangan Seorang Geisha (Memoirs of a G...
# 4744                                         魔戒首部曲：魔戒現身
# 4790                                    Le Petit Prince
# 4791                                      Trainspotting
#
#                         author  average_rating         isbn13 language_code  \
# 61               Charles Burns            4.00  9782840555520           NaN
# 63              Hiromu Arakawa            4.57  9789861156521           NaN
# ...

# %%
data[(data['average_rating']>4.5) & (data['ratings_count']< 10)]
# Out:
#                                                   title  \
# 63                                             鋼之鍊金術師 9
# 178                                            鋼之鍊金術師 6
# 224                             Stargirl LitPlans on CD
# 454   Literature Circle Guide: Bridge to Terabithia:...
# 584                       Falling Angels (Luc Actar #1)
# 681        Fanning the Flame: Bible  Cross  and Mission
# 696                  Tyrannosaurus Wrecks (Stanley  #1)
# 741   The John Deere Two-Cylinder Tractor Encycloped...
# 757   The American Campaign: U.S. Presidential Campa...
# 1837  The Goon Show  Volume 4: My Knees Have Fallen ...
# 1856                                          鋼之鍊金術師 10
# 1960  Wissenschaft der Logik: Die Lehre Vom Begriff ...
# 2244  Getting a Grip on the Basics: Building a Firm ...
# 2496                               Come Away My Beloved
# 3178  Organizational Architecture: Designs for Chang...
# 3438         Bill Gates: Computer Legend (Famous Lives)
# ...

# %%
data.groupby('language_code')['average_rating'].mean()
# Out:
# language_code
# en-GB    3.922523
# en-US    3.914800
# eng      3.931143
# ger      3.979773
# grc      2.366667
# jpn      4.252381
# lat      4.170000
# mul      4.116000
# spa      3.927938
# Name: average_rating, dtype: float64

# %%
data.head()
# Out:
#                                                title  \
# 0                        The Hunchback of Notre-Dame
# 1  La Cucina Di Lidia: Recipes and Memories from ...
# 2                                  Breach of Promise
# 3                  Brief Interviews with Hideous Men
# 4  The Killing Dance (Anita Blake  Vampire Hunter...
#
#                         author  average_rating         isbn13 language_code  \
# 0                  Victor Hugo            4.00  9780345472427         en-US
# 1  Lidia Matticchio Bastianich            4.14  9780767914222         en-GB
# 2             James Scott Bell            4.00  9780310243878           eng
# 3         David Foster Wallace            3.86  9780349111889           eng
# 4          Laurell K. Hamilton            4.13  9780425209066         en-US
#
#    num_pages  ratings_count  text_reviews_count          publisher  year
# 0      534.0            140                  22     Modern Library  2004
# ...

# %%
data.iloc[0:5,0:4]
# Out:
#                                                title  \
# 0                        The Hunchback of Notre-Dame
# 1  La Cucina Di Lidia: Recipes and Memories from ...
# 2                                  Breach of Promise
# 3                  Brief Interviews with Hideous Men
# 4  The Killing Dance (Anita Blake  Vampire Hunter...
#
#                         author  average_rating         isbn13
# 0                  Victor Hugo            4.00  9780345472427
# 1  Lidia Matticchio Bastianich            4.14  9780767914222
# 2             James Scott Bell            4.00  9780310243878
# 3         David Foster Wallace            3.86  9780349111889
# 4          Laurell K. Hamilton            4.13  9780425209066

# %%
data['num_pages'].mode()
# Out:
# 0    288.0
# dtype: float64

# %%
data['num_pages'].mean()
# Out:
# 341.0940205355345

# %%
data['num_pages'].max()
# Out:
# 3342.0

# %%
data[data['year']==2010]
# Out:
#                                                   title  \
# 40    The Walking Dead  Book One (The Walking Dead #...
# 359        Things: A Story of the Sixties; A Man Asleep
# 425   The Gap Into Vision: Forbidden Knowledge (Gap ...
# 985                                     Never Let Me Go
# 1696           The Unexpected Guest: A Play In Two Acts
# 1789  A Short History of Nearly Everything (Illustra...
# 2620                                         The Client
# 2695                                      Lord of Light
# 2706         Pimsleur German Level 1 CD: [Lessons 1-30]
# 3079                             Tim Burton: Interviews
# 3724                                     Less Than Zero
# 4460                                     Riddley Walker
# 4650  The Beatles' Story on Capitol Records  Part Tw...
# 4891   Judy Moody Declares Independence (Judy Moody #6)
# 4914  Earthquake in the Early Morning (Magic Tree Ho...
#
# ...

# %%
data[(data['publisher']=='DAW')&(data['average_rating']>4)]
# Out:
#                                                title           author  \
# 71                           By the Sword (Valdemar)  Mercedes Lackey
# 871         Storm Rising (Valdemar: Mage Storms  #2)  Mercedes Lackey
# 1523       Phoenix and Ashes (Elemental Masters  #3)  Mercedes Lackey
# 1583  To Battle the Gods (Jalav  Amazon Warrior  #5)     Sharon Green
# 3726        Oathblood (Valdemar: Vows and Honor  #3)  Mercedes Lackey
# 4367                     Joust (Dragon Jousters  #1)  Mercedes Lackey
#
#       average_rating         isbn13 language_code  num_pages  ratings_count  \
# 71              4.25  9780886774639           eng      492.0          18531
# 871             4.02  9780886777128         en-US      412.0          10781
# 1523            4.01  9780756402723           eng      480.0           6980
# 1583            4.07  9780886771287           eng      446.0             87
# 3726            4.06  9780886777739         en-GB      394.0           9786
# ...

# %%
data[(data['num_pages']>500)&(data['year']>2010)].count()
# Out:
# title                 5
# author                5
# average_rating        5
# isbn13                5
# language_code         5
# num_pages             5
# ratings_count         5
# text_reviews_count    5
# publisher             5
# year                  5
# dtype: int64

# %%
data[data['author']=='Agatha Christie'].count()
# Out:
# title                 21
# author                21
# average_rating        21
# isbn13                21
# language_code         21
# num_pages             19
# ratings_count         21
# text_reviews_count    21
# publisher             21
# year                  21
# dtype: int64

# %%
data[(data['language_code']=='spa')&(data['year']>2000)].count()
# Out:
# title                 84
# author                84
# average_rating        84
# isbn13                84
# language_code         84
# num_pages             83
# ratings_count         84
# text_reviews_count    84
# publisher             84
# year                  84
# dtype: int64

# %%
data1 = data[data['year']>2005]

# %%
data1['text_reviews_count'].max()
# Out:
# 52759

# %%
data1[data1['text_reviews_count']==52759]
# Out:
#                     title      author  average_rating         isbn13  \
# 1683  Water for Elephants  Sara Gruen            4.09  9781565125605
#
#      language_code  num_pages  ratings_count  text_reviews_count  \
# 1683           eng      335.0        1260027               52759
#
#             publisher  year
# 1683  Algonquin Books  2007
